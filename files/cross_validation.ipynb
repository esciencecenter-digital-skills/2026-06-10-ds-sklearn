# %% [markdown]
# # Cross-validation

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=True)

data, target = housing.data, housing.target

# %%
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
target
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(data, target)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
from sklearn.metrics import mean_absolute_error

target_predicted = regressor.predict(data)
score = mean_absolute_error(target, target_predicted)
score
# Out:
# 4.199913457496716e-17

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import ShuffleSplit

cv = ShuffleSplit(n_splits=40, test_size=0.3, random_state=0)
cv_results = cross_validate(
    regressor, data, target, cv=cv, scoring="neg_mean_absolute_error",
)

# %%
import pandas as pd

cv_results = pd.DataFrame(cv_results)
cv_results
# Out:
#     fit_time  score_time  test_score
# 0   0.095020    0.003093   -0.467900
# 1   0.087192    0.002387   -0.467090
# 2   0.086011    0.002806   -0.473435
# 3   0.088099    0.002369   -0.446230
# 4   0.082837    0.002499   -0.476201
# 5   0.080034    0.002268   -0.460548
# 6   0.079613    0.002448   -0.467880
# 7   0.078507    0.002058   -0.461317
# 8   0.078691    0.002426   -0.454336
# 9   0.080975    0.002237   -0.451519
# 10  0.077420    0.002015   -0.491423
# 11  0.088196    0.003011   -0.470903
# 12  0.091254    0.002404   -0.467206
# 13  0.088814    0.002610   -0.462687
# 14  0.090085    0.003060   -0.464542
# 15  0.091392    0.002602   -0.445455
# 16  0.088573    0.002690   -0.471120
# 17  0.092633    0.002671   -0.429130
# 18  0.089924    0.002641   -0.465146
# 19  0.090005    0.003120   -0.482535
# 20  0.087462    0.002958   -0.447374
# 21  0.089881    0.002426   -0.463941
# 22  0.091286    0.003309   -0.454913
# 23  0.088385    0.003193   -0.462008
# 24  0.086582    0.002835   -0.460613
# 25  0.082610    0.002434   -0.472690
# 26  0.077659    0.002084   -0.467769
# 27  0.077242    0.002119   -0.466743
# 28  0.078885    0.002176   -0.475981
# 29  0.084918    0.002966   -0.458813
# 30  0.086499    0.002183   -0.461801
# 31  0.090878    0.003400   -0.450172
# 32  0.089861    0.002608   -0.438782
# 33  0.086841    0.003075   -0.477325
# 34  0.083804    0.002560   -0.466237
# 35  0.078367    0.002072   -0.454931
# 36  0.077673    0.002117   -0.468452
# 37  0.077048    0.002371   -0.473239
# 38  0.084429    0.003037   -0.477900
# 39  0.086035    0.002751   -0.470417

# %%
cv_results["test_score"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
cv_results["test_score"].mean()
# Out:
# np.float64(-0.4636676085675065)

# %%
cv_results["test_score"].std()
# Out:
# np.float64(0.01209278475480522)

# %%
target.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
